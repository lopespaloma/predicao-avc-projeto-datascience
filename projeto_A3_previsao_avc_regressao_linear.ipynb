# %% [markdown]
# <a href="https://colab.research.google.com/github/lopespaloma/predicao-avc-projeto-datascience/blob/main/projeto_A3_previsao_avc_regressao_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## TREINAMENTO MODELO - REGRESSÃO LINEAR

# %%
import pandas as pd
import numpy as np

# %%
#arquivo csv - https://drive.google.com/file/d/1nqO1CM37CHyMd9bi4jG81Myd-iL_mSyX/view?usp=sharing

avc_linear = pd.read_csv('dados-regressao-linear.csv', delimiter= ',')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
avc_linear.head(500)
# Out:
#      Genero     Idade  Hipertensao  Doenca Cardiaca  Estado Civil  \
# 0       0.0  1.000000          0.0              0.0           1.0
# 1       1.0  0.890137          0.0              0.0           0.0
# 2       1.0  0.365234          0.0              0.0           1.0
# 3       1.0  0.182129          0.0              0.0           0.0
# 4       1.0  0.218750          0.0              0.0           0.0
# ..      ...       ...          ...              ...           ...
# 493     1.0  0.694824          0.0              0.0           1.0
# 494     1.0  0.768066          0.0              0.0           1.0
# 495     0.0  0.694824          0.0              0.0           1.0
# 496     0.0  0.169922          0.0              0.0           0.0
# 497     0.0  0.768066          0.0              0.0           1.0
#
#      Tipo de trabalho  Localizacao Residencial  Nivel medio de glicose  \
# 0            0.333333                      1.0                0.119287
# ...

# %%
x = avc_linear[['Genero', 'Idade', 'Hipertensao', 'Doenca Cardiaca', 'Estado Civil',
        'Tipo de trabalho', 'Localizacao Residencial', 'Nivel medio de glicose',
        'IMC', 'Condicao de fumante']]
y = avc_linear['AVC']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=50)

# %%
modelopreditor = LinearRegression()
modelopreditor.fit(X_train, y_train)
coeff = pd.DataFrame(modelopreditor.coef_, x.columns, columns = ['Coeficiente'])
coeff
# Out:
#                          Coeficiente
# Genero                      0.040433
# Idade                       1.155072
# Hipertensao                 0.147251
# Doenca Cardiaca             0.051586
# Estado Civil               -0.088206
# Tipo de trabalho           -0.174917
# Localizacao Residencial     0.032715
# Nivel medio de glicose      0.154826
# IMC                        -0.495587
# Condicao de fumante         0.090339

# %%
predictions = modelopreditor.predict(X_test)
X_test.head()
# Out:
#      Genero     Idade  Hipertensao  Doenca Cardiaca  Estado Civil  \
# 330     1.0  0.804688          0.0              0.0           1.0
# 372     1.0  0.694824          0.0              0.0           1.0
# 358     1.0  0.975586          0.0              0.0           1.0
# 353     0.0  0.389648          0.0              0.0           1.0
# 344     0.0  0.096680          0.0              0.0           0.0
#
#      Tipo de trabalho  Localizacao Residencial  Nivel medio de glicose  \
# 330          0.333333                      0.0                0.443357
# 372          0.333333                      1.0                0.656264
# 358          0.333333                      1.0                0.944096
# 353          0.333333                      0.0                0.153310
# 344          0.000000                      0.0                0.225787
#
#           IMC  Condicao de fumante
# 330  0.197022                  1.0
# 372  0.277205                  1.0
# ...

# %%
print(predictions)
# Out:
# [ 0.72603122  0.62507209  0.96466141  0.1135276  -0.05805717  0.63199971
#   0.08431479  0.33502592  0.63133214  0.12326328  0.88156622  0.47684037
#   0.31983885  0.57700283  0.13085084  0.05456275  0.30449191 -0.0357411
#   0.19360356  0.5391467   0.81198081  0.72167546 -0.04624063  0.02220379
#   0.2935046   0.18359809  0.50478922  0.88110725  0.0972555   0.34603965
#   0.03852867  0.05280392 -0.06904874  0.36160918  0.73710936  0.96159811
#   0.64995092  0.59140582  0.91782163  0.8962416   0.82985919  0.43902105
#   0.70643488  0.55010151  0.71057765  0.79030928  0.10320077  0.78847374
#   0.39038145  0.08826766  0.6921669   0.12649201  0.11245511  0.03518645
#   0.57642585  0.2203637   0.1610683  -0.02554114  0.5040116   0.67877743
#   0.7445101   0.22704522  0.37590281  0.44119901  0.08273242  0.46288075
#   1.00631014  0.10191674 -0.00310813  0.575681    0.07221119  0.41062984
#   0.31702363  0.69765464  0.47032227  0.14757889  0.46233528  0.826946
# ...

# %%
y_test.head()
# Out:
# 330    1.0
# 372    1.0
# 358    1.0
# 353    0.0
# 344    0.0
# Name: AVC, dtype: float64

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.3112810576246246
# MSE: 0.160016104617203
# RMSE: 0.4000201302649693
